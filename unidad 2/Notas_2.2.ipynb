# %%
for i in range (1,5):
    print ("Número i")
# Out:
# Número i
# Número i
# Número i
# Número i

# %%
suma = 0

for i in range(1, 11):  
    suma += i

print("La suma de los primeros 10 números es:", suma)
# Out:
# La suma de los primeros 10 números es: 55

# %%
nombres = ["Ed", "Jorge", "María", "Luisa"]

for nombre in nombres:
    print("Hola,", nombre)
# Out:
# Hola, Ed
# Hola, Jorge
# Hola, María
# Hola, Luisa

# %%
Cumple = int(input("¿Cuál es tu edad?"))
for i in range(1, Cumple):
    print("Feliz cumpleaños número",i)
print("Feliz cumpleanos numero", Cumple)
# Out:
# ¿Cuál es tu edad? 7
# Feliz cumpleaños número 1
# Feliz cumpleaños número 2
# Feliz cumpleaños número 3
# Feliz cumpleaños número 4
# Feliz cumpleaños número 5
# Feliz cumpleaños número 6
# Feliz cumpleanos numero 7

# %%
#Hacer que con un input se agregue la edad
opcion = 2
if opcion == 1:
    print("Has elegido guardar el archivo")
elif opcion == 2:
    print("Has elegido abrir un archivo")
elif opcion == 3:
    print("Has elegido salir del programa")
else:
    print("Opción no válida")
# Out:
# Has elegido abrir un archivo

# %%
#Hacer que con un input se agregue la calificación
calificacion = int(input("Introduce la calificacion"))

if calificacion >= 90:
    print("Excelente")
elif calificacion >= 70:
    print("Aprobado")
else:
    print("Reprobado")
# Out:
# Introduce la calificacion 9291239
# Excelente

# %%
numero_secreto = 7
while adivinanza:
    adivinanza = int(input("adivina el numero de (1-10):"))
    if adivinanza == 7:
        print("¡Correcto! El número era", numero_secreto)
        break
    else:
        print("El numero no es correcto")
# Out:
# adivina el numero de (1-10): 5
# El numero no es correcto
# adivina el numero de (1-10): 6
# El numero no es correcto
# adivina el numero de (1-10): 8
# El numero no es correcto
# adivina el numero de (1-10): 7
# ¡Correcto! El número era 7

# %%
contador = 1

while contador <= 7:
    print("Número:", contador)
    contador += 1  # incrementa el contador
# Out:
# Número: 1
# Número: 2
# Número: 3
# Número: 4
# Número: 5
# Número: 6
# Número: 7
